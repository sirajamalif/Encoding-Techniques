# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\User\Downloads\supershops.csv")
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# Profit             0
# dtype: int64

# %%
# Handle NaN Value
mean = df.Transport.mean()
median = df.Transport.median()

# %%
mean
# Out:
# 215331.7324489796

# %%
median
# Out:
# 214634.81

# %%
df.Transport = df.Transport.fillna(median) # fill NaN values

# %%
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          0
# Area               0
# Profit             0
# dtype: int64

# %%
df.Transport.head()
# Out:
# 0    471784.10
# 1    443898.53
# 2    407934.54
# 3    383199.62
# 4    366168.42
# Name: Transport, dtype: float64

# %% [markdown]
# # Encoding (Most Important)

# %%
df.Area.unique() # Ki ki unique value ache segula dekhay
# Out:
# array(['Dhaka', 'Ctg', 'Rangpur'], dtype=object)

# %%
df.Area = df.Area.replace(['Dhaka', 'Ctg', 'Rangpur'],[3,2,1])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_14704\2097782339.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.Area = df.Area.replace(['Dhaka', 'Ctg', 'Rangpur'],[3,2,1])

# %%
df.Area.head()
# Out:
# 0    3
# 1    2
# 2    1
# 3    3
# 4    1
# Name: Area, dtype: int64

# %%
#LABEL ENCODING

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv(r"C:\Users\User\Downloads\supershops.csv")
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
label = LabelEncoder()

# %%
df.Area = label.fit_transform(df['Area'])

# %%
df.Area.head()
# Out:
# 0    1
# 1    0
# 2    2
# 3    1
# 4    2
# Name: Area, dtype: int32

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     0  191792.06
# 2        153441.51       101145.55  407934.54     2  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     2  166187.94

# %%
# jodi 1 er beshi column thake tahole loop use kore label encoding kora jay
for column in df.columns:
    if df[column].dtype == np.number:
        continue
    else:
        df[column] = LabelEncoder().fit_transform(df[column])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_14704\1480367624.py:3: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:
# C:\Users\User\AppData\Local\Temp\ipykernel_14704\1480367624.py:3: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     0  191792.06
# 2        153441.51       101145.55  407934.54     2  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     2  166187.94

# %% [markdown]
# # One-hot Encoding

# %%
df = pd.read_csv(r"C:\Users\User\Downloads\supershops.csv")
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
dummy_variables= pd.get_dummies(df['Area'],dtype=int,drop_first=True)

# %%
dummy_variables.head()
# Out:
#    Dhaka  Rangpur
# 0      1        0
# 1      0        0
# 2      0        1
# 3      1        0
# 4      0        1

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df1 = df.drop('Area',axis=1) # axis=0 means row and 1 means column

# %%
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit
# 0        114523.61       136897.80  471784.10  192261.83
# 1        162597.70       151377.59  443898.53  191792.06
# 2        153441.51       101145.55  407934.54  191050.39
# 3        144372.41       118671.85  383199.62  182901.99
# 4        142107.34        91391.77  366168.42  166187.94

# %%
df2 = pd.concat([df1,dummy_variables], axis=1)

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit  Dhaka  Rangpur
# 0        114523.61       136897.80  471784.10  192261.83      1        0
# 1        162597.70       151377.59  443898.53  191792.06      0        0
# 2        153441.51       101145.55  407934.54  191050.39      0        1
# 3        144372.41       118671.85  383199.62  182901.99      1        0
# 4        142107.34        91391.77  366168.42  166187.94      0        1

# %%
df2.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Profit             0
# Dhaka              0
# Rangpur            0
# dtype: int64

# %%
median = df2.Transport.median()
df2.Transport = df2.Transport.fillna(median)

# %%
df2.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          0
# Profit             0
# Dhaka              0
# Rangpur            0
# dtype: int64

# %%
# Step 1: Split dependent & independent variables
x = df2.drop('Profit', axis=1)  # independent variables
y = df2['Profit']               # dependent variable

# %%
#  Step 2: Train linear regression model
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
#  Step 3: Predict
'''Evaluate the model. MSE shows How far off your predictions are, on average (squared). Lower = better.
and R² shows How well your model explains the variability in the data. 
R² = 1.0 → perfect prediction 
R² = 0.0 → model predicts no better than the mean 
Negative → model is doing worse than predicting the average
from sklearn.metrics import mean_squared_error, r2_score'''

from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)

print("MSE:", mse)
print("R² score:", r2)
# Out:
# MSE: 151847312.73953566
# R² score: 0.9046242980065675

# %% [markdown]
# # ORDINAL ENCODER

# %%
df = pd.read_csv(r"C:\Users\User\Downloads\supershops.csv")
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
df.Area.unique()
# Out:
# array(['Dhaka', 'Ctg', 'Rangpur'], dtype=object)

# %%
city_list = ['Dhaka', 'Ctg', 'Rangpur']

# %%
ordinal = OrdinalEncoder(categories=[city_list])

# %%
encoded_values = ordinal.fit_transform(df[['Area']])

# %%
new_area = pd.DataFrame(encoded_values ,columns=['Area'])

# %%
new_area.head()
# Out:
#    Area
# 0   0.0
# 1   1.0
# 2   2.0
# 3   0.0
# 4   2.0

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df.Area = new_area

# %%
df.head() # df er Area drop kore new_area df a concat koreo kora jay
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10   0.0  192261.83
# 1        162597.70       151377.59  443898.53   1.0  191792.06
# 2        153441.51       101145.55  407934.54   2.0  191050.39
# 3        144372.41       118671.85  383199.62   0.0  182901.99
# 4        142107.34        91391.77  366168.42   2.0  166187.94

# %% [markdown]
# # HASHING-ENCODER

# %%
df = pd.read_csv(r"C:\Users\User\Downloads\supershops.csv")
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
import category_encoders as ce

# %%
encoders = ce.HashingEncoder(cols='Area',n_components=3) #obj create korlam, n_components slelect kore nile easy hoy

# %%
encoders.fit_transform(df).head() # Collision hoy and data missing hoar chance thake tai beshir bhaag khetre one hot encoder use korte hbe for most cases
# Out:
#    col_0  col_1  col_2  Marketing Spend  Administration  Transport     Profit
# 0      0      1      0        114523.61       136897.80  471784.10  192261.83
# 1      0      0      1        162597.70       151377.59  443898.53  191792.06
# 2      1      0      0        153441.51       101145.55  407934.54  191050.39
# 3      0      1      0        144372.41       118671.85  383199.62  182901.99
# 4      1      0      0        142107.34        91391.77  366168.42  166187.94
